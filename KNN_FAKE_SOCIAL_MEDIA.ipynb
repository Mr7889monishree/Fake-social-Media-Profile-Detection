# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr7889monishree/Fake-social-Media-Profile-Detection/blob/main/KNN_FAKE_SOCIAL_MEDIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load training and testing datasets
df_train = pd.read_csv('/content/insta_train.csv')
df_test = pd.read_csv('/content/insta_test.csv')

# %%
# Data preprocessing
x_train = df_train.drop(columns='fake', axis=1)
y_train = df_train['fake']
x_test = df_test.drop(columns='fake', axis=1)
y_test = df_test['fake']

# %%
# Standardize the input features
scaler_x = StandardScaler()
X_train = scaler_x.fit_transform(x_train)
X_test = scaler_x.transform(x_test)

# %%
# Initialize and train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  # n_neighbors can be tuned
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Make predictions on the test set
y_prediction = knn_model.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_prediction)
precision = precision_score(y_test, y_prediction, average='binary')
recall = recall_score(y_test, y_prediction, average='binary')

# %%
print("KNN Model Evaluation:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# KNN Model Evaluation:
# Accuracy: 0.8833333333333333
# Precision: 0.8833333333333333
# Recall: 0.8833333333333333

# %%
# Predictive System
input_data = (1,0,2,0,0,18,0,1,118,461,1055)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshape = input_data_as_numpy_array.reshape(1, -1)
std_data = scaler_x.transform(input_data_reshape)

# Make prediction with the KNN model
prediction = knn_model.predict(std_data)

# Interpret the result
print("Prediction:", prediction)
if prediction[0] == 0:
    print('This is the true profile')
else:
    print('This is the fake profile')
# Out:
# Prediction: [0]
# This is the true profile
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(knn_model, 'knn_model.pkl')
# Out:
# ['knn_model.pkl']
